# %% [markdown]
# #PRODIGY_DS_02
#
# Task:2    perform data cleaning and EDA on a dataset of your choice. Explore the relationship between variables and identify the patterns and trends.
#
# Dataset Source: Kaggle
#
#
# Data Cleaning:
# The dataset is cleaned using Power Query feature of Power BI. It helps to clean and transform the data.

# %% [markdown]
# ![Screenshot (178).png](data:image/png;base64,...)

# %% [markdown]
# #Data Visualization:
#
#
#
#
# *   Total Number of people survived
#
#
#
# ![Screenshot (179).png](data:image/png;base64,...)

# %% [markdown]
# 1.   Count of survived by cabin : The totalnumber of people survived according to particular cabin are given below.
#
# ![Screenshot (176).png](data:image/png;base64,...)

# %% [markdown]
# *   Count of survived by embarked
#
#
#
# ![Screenshot (174).png](data:image/png;base64,...)

# %% [markdown]
# *   Total number of people survived according to Gender are as follows
#
# ![Screenshot (175).png](data:image/png;base64,...)

# %% [markdown]
# *   Total number of people survived according to the age group
#
# ![Screenshot (177).png](data:image/png;base64,...)

# %% [markdown]
# #Dashboard
#
# ![Screenshot (173).png](data:image/png;base64,...)
